# %%
import threading
import numpy as np
import tensorflow as tf
import pylab
import time
import gym
from keras.layers import Dense, Input
from keras.models import Model
from keras.optimizers import Adam
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# global variables for threading
episode = 0
scores = []

EPISODES = 2000

# %%
# This is A3C(Asynchronous Advantage Actor Critic) agent(global) for the Cartpole
# In this example, we use A3C algorithm
class A3CAgent:
    def __init__(self, state_size, action_size, env_name):
        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # get gym environment name
        self.env_name = env_name

        # these are hyper parameters for the A3C
        self.actor_lr = 0.001
        self.critic_lr = 0.001
        self.discount_factor = .99
        self.hidden1, self.hidden2 = 24, 24
        self.threads = 8

        # create model for actor and critic network
        self.actor, self.critic = self.build_model()

        # method for training actor and critic network
        self.optimizer = [self.actor_optimizer(), self.critic_optimizer()]

        self.sess = tf.InteractiveSession()
        K.set_session(self.sess)
        self.sess.run(tf.global_variables_initializer())

    # approximate policy and value using Neural Network
    # actor -> state is input and probability of each action is output of network
    # critic -> state is input and value of state is output of network
    # actor and critic network share first hidden layer
    def build_model(self):
        state = Input(batch_shape=(None,  self.state_size))
        shared = Dense(self.hidden1, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_uniform')(state)

        actor_hidden = Dense(self.hidden2, activation='relu', kernel_initializer='glorot_uniform')(shared)
        action_prob = Dense(self.action_size, activation='softmax', kernel_initializer='glorot_uniform')(actor_hidden)

        value_hidden = Dense(self.hidden2, activation='relu', kernel_initializer='he_uniform')(shared)
        state_value = Dense(1, activation='linear', kernel_initializer='he_uniform')(value_hidden)

        actor = Model(inputs=state, outputs=action_prob)
        critic = Model(inputs=state, outputs=state_value)

        actor._make_predict_function()
        critic._make_predict_function()

        actor.summary()
        critic.summary()

        return actor, critic

    # make loss function for Policy Gradient
    # [log(action probability) * advantages] will be input for the back prop
    # we add entropy of action probability to loss
    def actor_optimizer(self):
        action = K.placeholder(shape=(None, self.action_size))
        advantages = K.placeholder(shape=(None, ))

        policy = self.actor.output

        good_prob = K.sum(action * policy, axis=1)
        eligibility = K.log(good_prob + 1e-10) * K.stop_gradient(advantages)
        loss = -K.sum(eligibility)

        entropy = K.sum(policy * K.log(policy + 1e-10), axis=1)

        #actor_loss = loss + 0.01*entropy
        actor_loss = loss


        optimizer = Adam(lr=self.actor_lr)
        updates = optimizer.get_updates(self.actor.trainable_weights, [], actor_loss)
        train = K.function([self.actor.input, action, advantages], [], updates=updates)
        return train

    # make loss function for Value approximation
    def critic_optimizer(self):
        discounted_reward = K.placeholder(shape=(None, ))

        value = self.critic.output

        loss = K.mean(K.square(discounted_reward - value))

        optimizer = Adam(lr=self.critic_lr)
        updates = optimizer.get_updates(self.critic.trainable_weights, [], loss)
        train = K.function([self.critic.input, discounted_reward], [], updates=updates)
        return train

    # make agents(local) and start training
    def train(self):
        # self.load_model('./save_model/cartpole_a3c.h5')
        agents = [Agent(i, self.actor, self.critic, self.optimizer, self.env_name, self.discount_factor,
                        self.action_size, self.state_size) for i in range(self.threads)]

        for agent in agents:
            agent.start()

        while True:
            time.sleep(20)

            plot = scores[:]
            pylab.plot(range(len(plot)), plot, 'b')
            pylab.savefig("./save_graph/cartpole_a3c.png")

            self.save_model('./save_model/cartpole_a3c.h5')

    def save_model(self, name):
        self.actor.save_weights(name + "_actor.h5")
        self.critic.save_weights(name + "_critic.h5")

    def load_model(self, name):
        self.actor.load_weights(name + "_actor.h5")
        self.critic.load_weights(name + "_critic.h5")

# %%
# This is Agent(local) class for threading
class Agent(threading.Thread):
    def __init__(self, index, actor, critic, optimizer, env_name, discount_factor, action_size, state_size):
        threading.Thread.__init__(self)

        self.states = []
        self.rewards = []
        self.actions = []

        self.index = index
        self.actor = actor
        self.critic = critic
        self.optimizer = optimizer
        self.env_name = env_name
        self.discount_factor = discount_factor
        self.action_size = action_size
        self.state_size = state_size

    # Thread interactive with environment
    def run(self):
        global episode
        env = gym.make(self.env_name)
        while episode < EPISODES:
            state = env.reset()
            score = 0
            while True:
                action = self.get_action(state)
                next_state, reward, done, _ = env.step(action)
                score += reward

                self.memory(state, action, reward)

                state = next_state

                if done:
                    episode += 1
                    print("episode: ", episode, "/ score : ", score)
                    scores.append(score)
                    self.train_episode(score != 500)
                    break

    # In Policy Gradient, Q function is not available.
    # Instead agent uses sample returns for evaluating policy
    def discount_rewards(self, rewards, done=True):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        if not done:
            running_add = self.critic.predict(np.reshape(self.states[-1], (1, self.state_size)))[0]
        for t in reversed(range(0, len(rewards))):
            running_add = running_add * self.discount_factor + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    # save <s, a ,r> of each step
    # this is used for calculating discounted rewards
    def memory(self, state, action, reward):
        self.states.append(state)
        act = np.zeros(self.action_size)
        act[action] = 1
        self.actions.append(act)
        self.rewards.append(reward)

    # update policy network and value network every episode
    def train_episode(self, done):
        discounted_rewards = self.discount_rewards(self.rewards, done)

        values = self.critic.predict(np.array(self.states))
        values = np.reshape(values, len(values))

        advantages = discounted_rewards - values

        self.optimizer[0]([self.states, self.actions, advantages])
        self.optimizer[1]([self.states, discounted_rewards])
        self.states, self.actions, self.rewards = [], [], []

    def get_action(self, state):
        policy = self.actor.predict(np.reshape(state, [1, self.state_size]))[0]
        return np.random.choice(self.action_size, 1, p=policy)[0]

# %%
if __name__ == "__main__":
    env_name = 'CartPole-v1'
    env = gym.make(env_name)

    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    env.close()

    global_agent = A3CAgent(state_size, action_size, env_name)
    global_agent.train()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_7 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_9 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 25
# =================================================================
# Total params: 745
# Trainable params: 745
# Non-trainable params: 0
# _________________________________________________________________
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# episode:  1 / score :  10.0
# episode:  2 / score :  16.0
# episode:  3 / score :  17.0
# episode:  4 / score :  25.0
# episode: episode:  6 / score :  18.0
#  5 / score :  25.0
# episode:  7 episode:  8 / score :  / score : 35.0
#  30.0
# episode:  episode:  10 / score :  16.0
# 9 / score :  12.0
# episode: episode:  12 / score :  15.0
#  11 / score : episode:  22.0
#  13 / score :  16.0
# episode:  14 / score :  9.0
# episode:  15 / score :  13.0
# episode: episode:  16  17/ score :   / score :  21.0
# 40.0
# episode:  18 / score :  10.0
# episode:  19 / score :  13.0
# episode:  20 / score :  12.0
# episode:  21 / score :  13.0
# episode:  22 / score :  16.0
# episode:  23 / score :  24.0
# episode:  24 / score :  15.0
# episode:  25 / score :  10.0
# episode: episode:  26 / score :  32.0
#  27 / score :  21.0
# episode: episode:   28 / score :  28.0
# 29 / score :  17.0
# episode:  30 / score :  29.0
# episode:  31 / score :  11.0
# episode:  32 / score :  31.0
# episode:  33 / score :  13.0
# episode:  34episode:  / score :  17.0
#  35 / score :  9.0
# episode:  36 / score :  36.0
# episode:  37 / score :  12.0
# episode:  38 / score :  24.0
# episode:  39 / score :  25.0
# episode:  40 / score :  21.0
# episode: episode:   42 / score : 41 / score :  12.0
#  64.0
# episode:  43 / score :  20.0
# episode:  44 / score :  14.0
# episode:  45 / score :  19.0
# episode:  46 / score :  16.0
# episode:  47 / score :  19.0
# episode:  48 / score :  19.0
# episode: episode:  49 50 / score :  22.0
#  / score :  28.0
# episode:  51 / score :  15.0
# episode:  52 / score :  27.0
# episode:  53 / score : episode:  22.0
#  54 / score :  41.0
# episode:  55 / score :  23.0
# episode: episode:  57 / score :  19.0
#  56 / score :  15.0
# episode:  58 / score :  34.0
# episode: episode:  59 / score :  13.0
#  60 / score :  12.0
# episode:  61 / score :  9.0
# episode:  62 / score :  25.0
# episode:  63 / score :  12.0
# episode:  64 / score :  13.0
# episode: episode:   66 / score :  6512.0 / score :  16.0
#
# episode:  67 / score :  11.0
# episode:  68 episode:  / score : 69  43.0
# / score :  14.0
# episode:  70 episode:  71 / score :  11.0
# / score :  28.0
# episode:  72 / score :  34.0
# episode:  73 / score :  12.0
# episode:  74 / score :  23.0
# episode:  75 / score :  19.0
# episode: episode:  77 / score :  13.0
#  76 / score :  30.0
# episode: episode:  78 79 / score :  19.0
# episode:  80 / score :  19.0
#  / score :  50.0
# episode:  81 / score :  12.0
# episode: episode:  82 / score :  30.0
#  83 / score :  47.0
# episode:  episode: 84  85 / score :  21.0
# episode:  86 / score :  59.0
# / score :  45.0
# episode: episode:  87 / score :  31.0
#  88 / score :  24.0
# episode:  89 / score :  17.0
# episode:  90 / score :  51.0
# episode: episode:  92  / score :  31.0
# 91 / score :  17.0
# episode:  93 / score :  22.0
# episode:  94 / score :  15.0
# episode:  95 / score :  27.0
# episode:  96 / score :  30.0
# episode:  97 / score :  26.0
# episode:  98 / score :  18.0
# episode:  99 / score :  29.0
# episode: episode:  100 / score :  28.0
#  101 / score :  12.0
# episode:  102 / score :  50.0
# episode:  103 / score :  20.0
# episode:  104 / score :  49.0
# episode:  105 / score :  37.0
# episode: episode:  106 / score :  66.0
#  107 / score :  60.0
# episode:  108 / score :  46.0
# episode:  109 / score :  34.0
# episode:  110 / score :  22.0
# episode:  111 / score :  98.0
# episode:  112 / score :  19.0
# episode:  113 / score :  23.0
# episode:  114 / score :  29.0
# episode:  115episode:  116 / score :  49.0
#  / score :  32.0
# episode:  117 / score :  48.0
# episode:  118 / score :  40.0
# episode:  119 / score :  38.0
# episode:  120 / score :  74.0
# episode:  121 / score :  34.0
# episode:  122 / score :  22.0
# episode:  123 / score :  22.0
# episode:  124 / score :  19.0
# episode:  125 / score :  61.0
# episode:  126 / score :  54.0
# episode:  127 / score :  49.0
# episode:  128 / score :  39.0
# episode:  129 / score :  34.0
# episode:  episode: 130  / score :  80.0
# 131 / score :  32.0
# episode:  132 / score :  10.0
# episode: episode:  133  134 / score : episode:  / score :  135 / score :  11.0
#  42.0
# 52.0
# episode:  136 episode: / score :  78.0
#  137 / score :  57.0
# episode:  138 / score :  45.0
# episode:  139 / score :  17.0
# episode:  140 / score :  58.0
# episode:  141 / score : episode:  16.0
#  142 / score :  23.0
# episode:  143episode:   144 / score :  49.0
# / score :  100.0
# episode:  145 / score :  39.0
# episode:  146episode:   147 / score :  60.0
# / score :  32.0
# episode:  148 / score :  71.0
# episode:  149 / score :  22.0
# episode:  150 / score :  79.0
# episode:  151 / score :  48.0
# episode:  episode: 152 153 / score :  37.0
#  / score :  49.0
# episode:  154 / score :  166.0
# episode:  155 / score :  66.0
# episode:  156 episode: / score :  48.0
#  157 / score :  81.0
# episode:  158 / score :  42.0
# episode:  159 / score :  49.0
# episode:  160 / score :  episode: 76.0episode:
#  162 / score :  34.0
#  161 / score :  32.0
# episode:  163 / score :  160.0
# episode:  164 / score :  58.0
# episode:  165 / score :  64.0
# episode:  166 / score :  65.0
# episode:  167 / score :  33.0
# episode:  168 / score :  47.0
# episode:  169 / score :  55.0
# episode:  170 / score :  44.0
# episode:  171 / score :  episode:  172 / score :  39.0
# episode:  34.0
# 173 / score :  60.0
# episode:  174 / score :  146.0
# episode: episode:   176 / score :  16.0
# 175 / score :  65.0
# episode:  177 / score :  27.0
# episode:  178 / score :  65.0
# episode:  179 / score :  67.0
# episode:  180 / score :  47.0
# episode:  episode:  182181 / score :   65.0
# / score :  36.0
# episode:  183 / score :  92.0
# episode:  184episode:  185 / score :  75.0
#  / score :  32.0
# episode:  186 / score :  199.0
# episode:  187 / score :  94.0
# episode:  188 / score :  37.0
# episode:  189 / score :  76.0episode:
#  190 / score :  62.0
# episode:  191 / score :  83.0
# episode:  192 / score :  41.0
# episode:  193 / score :  79.0
# episode:  194 / score :  50.0
# episode:  195 / score :  74.0
# episode: episode:  197 / score :  38.0
#  196 / score :  38.0
# episode:  198 / score :  39.0
# episode:  199 / score :  57.0
# episode:  200 / score :  50.0
# episode:  201 / score :  17.0
# episode:  202 / score :  55.0
# episode:  203 / score :  36.0
# episode: episode:  204 / score :  66.0
#  205 / score :  138.0
# episode:  206 / score :  50.0
# episode:  207 / score :  44.0
# episode:  208 / score :  39.0
# episode:  209 / score :  133.0
# episode:  210 / score :  139.0
# episode:  211 / score :  49.0
# episode:  212 / score :  78.0
# episode:  213 / score :  149.0
# episode:  214 / score :  42.0
# episode:  215 / score :  162.0
# episode: episode:  217 / score :  91.0
#  216 / score :  69.0
# episode:  218 / score :  121.0
# episode:  219 / score :  74.0
# episode:  220 / score :  82.0
# episode:  221 / score :  23.0
# episode:  222 / score :  54.0
# episode:  223 / score :  128.0
# episode:  224 / score :  52.0
# episode:  225 / score :  165.0
# episode:  226 / score :  105.0
# episode:  227 / score :  76.0
# episode:  228 / score :  113.0
# episode:  229 / score :  45.0
# episode:  230 / score :  43.0
# episode:  231 / score :  188.0
# episode:  232 / score :  111.0
# episode:  233 / score :  93.0
# episode:  234 / score :  89.0
# episode:  235 / score :  72.0
# episode:  236 / score :  156.0
# episode:  237 / score :  122.0
# episode:  238 / score :  50.0
# episode:  239 / score :  86.0
# episode:  episode: 240 / score :  195.0
#  241 / score :  105.0
# episode:  242 / score :  51.0
# episode:  243 / score :  48.0
# episode:  244 / score :  25.0
# episode:  245 / score :  124.0
# episode:  246 / score :  132.0
# episode:  247 / score :  173.0
# episode:  248 / score :  86.0
# episode:  249 / score :  120.0
# episode:  250 / score :  121.0
# episode:  251 / score :  173.0
# episode:  252 / score :  142.0
# episode:  253 / score :  204.0
# episode:  254 / score :  92.0
# episode:  255 / score :  255.0
# episode:  256 / score :  172.0
# episode:  257 / score :  232.0
# episode:  258 / score :  71.0
# episode:  259 / score :  93.0
# episode:  260 / score :  176.0
# episode:  261 / score :  149.0
# episode:  262 / score :  212.0
# episode:  263 / score :  125.0
# episode:  264 episode: / score :  265 / score :  101.0
#  109.0
# episode:  266 / score :  220.0
# episode:  267 / score :  272.0
# episode:  268 / score :  299.0
# episode:  269 / score :  120.0
# episode:  270 / score :  117.0
# episode:  271 / score :  232.0
# episode:  272 / score :  154.0
# episode:  273 / score :  95.0
# episode:  274 / score :  82.0
# episode:  275 / score :  147.0
# episode:  276 / score :  265.0
# episode:  277 / score :  150.0
# episode:  278 / score :  126.0
# episode:  279 / score :  124.0
# episode:  280 / score :  126.0
# episode:  episode: 281 282  / score :  101.0
# / score :  169.0
# episode:  283 / score :  110.0
# episode:  284 / score :  119.0
# episode:  285 / score :  243.0
# episode:  286 / score :  85.0
# episode:  287 / score :  117.0
# episode:  288 / score :  280.0
# episode:  289 / score :  220.0
# episode:  290 / score :  220.0
# episode:  291 / score :  141.0
# episode:  292 / score :  169.0
# episode:  293 / score :  311.0
# episode:  294 / score :  268.0
# episode:  295 / score :  121.0
# episode:  296 / score :  449.0
# episode: episode:  297 / score :  300.0
#  298 / score :  187.0
# episode:  299 / score :  214.0
# episode:  300 / score :  98.0
# episode:  301 / score :  153.0
# episode:  302 / score :  134.0
# episode:  303 / score :  227.0
# episode:  304 / score :  184.0
# episode:  305 / score :  255.0
# episode:  306 / score :  233.0
# episode:  307 / score :  308.0
# episode:  308 / score :  286.0
# episode:  309 / score :  298.0
# episode:  310 / score :  308.0
# episode:  311 / score :  106.0
# episode:  312 / score :  440.0
# episode:  313 / score :  222.0
# episode:  314 / score :  112.0
# episode:  315 / score :  246.0
# episode:  316 / score :  254.0
# episode:  317 / score :  169.0
# episode:  318 / score :  309.0
# episode:  319 / score :  229.0
# episode:  320 / score : episode:  149.0
#  321 / score :  117.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-66226957abc6> in <module>
#       9
#      10     global_agent = A3CAgent(state_size, action_size, env_name)
# ---> 11     global_agent.train()
#
# <ipython-input-7-1751df61fa4d> in train(self)
#     103             plot = scores[:]
#     104             pylab.plot(range(len(plot)), plot, 'b')
# --> 105             pylab.savefig("./save_graph/cartpole_a3c.png")
#     106
#     107             self.save_model('./save_model/cartpole_a3c.h5')
#
# C:\Anaconda\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     714 def savefig(*args, **kwargs):
#     715     fig = gcf()
# --> 716     res = fig.savefig(*args, **kwargs)
#     717     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     718     return res
#
# C:\Anaconda\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# C:\Anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# C:\Anaconda\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# C:\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# C:\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './save_graph/cartpole_a3c.png'
# episode:  322 / score :  551.0
# episode:  323 / score :  202.0
# episode:  324 / score :  163.0
# episode:  325 / score :  97.0
# episode:  326 / score :  353.0
# episode:  327 / score :  207.0
# episode:  328 / score :  127.0
# episode:  329 / score :  270.0
# episode:  330 / score :  298.0
# episode:  331 / score :  347.0
# episode:  332 / score :  212.0
# episode:  333 / score :  443.0
# episode:  334 / score :  308.0
# episode:  335 / score :  206.0
# episode:  336 / score :  228.0
# episode:  337 / score :  361.0
# episode:  338 / score :  175.0
# episode:  339 / score :  130.0
# episode:  340 / score :  233.0
# episode:  341 / score :  143.0
# episode:  342 / score :  452.0
# episode:  343 / score :  568.0
# episode:  344 / score :  636.0
# episode:  345 / score :  301.0
# episode:  346 / score :  585.0
# episode:  347 / score :  142.0
# episode:  348 / score :  434.0
# episode:  349 / score :  296.0
# episode:  350 / score :  172.0
# episode:  351 / score :  416.0
# episode:  352 / score :  653.0
# episode:  353 / score :  279.0
# episode:  354 / score :  78.0
# episode:  355 / score :  177.0
# episode:  356 / score :  654.0
# episode:  357 / score :  353.0
# episode:  358 / score :  215.0
# episode:  359 / score :  350.0
# episode:  360 / score :  415.0
# episode:  361 / score :  74.0
# episode:  362 / score :  100.0
# episode:  363 / score :  1140.0
# episode:  364 / score :  263.0
# episode:  365 / score :  181.0
# episode:  366 / score :  747.0
# episode:  367 / score :  800.0
# episode:  368 / score :  563.0
# episode:  369 / score :  713.0
# episode:  370 / score :  550.0
# episode:  371 / score :  255.0
# episode:  372 / score :  82.0
# episode:  373 / score :  468.0
# episode:  374 / score :  471.0
# episode:  375 / score :  218.0
# episode:  376 / score :  349.0
# episode:  377 / score :  348.0
# episode:  378 / score :  122.0
# episode:  379 / score :  404.0
# episode:  380 / score :  371.0
# episode:  381 / score :  275.0
# episode:  382 / score :  560.0
# episode:  383 / score :  402.0
# episode:  384 / score :  428.0
# episode:  385 / score :  250.0
# episode:  386 / score :  296.0
# episode:  387 / score :  309.0
# episode:  388 / score :  688.0
# episode:  389 / score :  574.0
# episode:  390 / score :  272.0
# episode:  391 / score :  218.0
# episode:  392 / score :  385.0
# episode:  393 / score :  745.0
# episode:  394 / score :  1333.0
# episode:  395 / score :  378.0
# episode:  396 / score :  944.0
# episode:  397 / score :  797.0
# episode:  398 / score :  497.0
# episode:  399 / score :  239.0
# episode:  400 / score :  968.0
# episode:  401 / score :  385.0
# episode:  402 / score :  590.0
# episode:  403 / score :  531.0
# episode:  404 / score :  928.0
# episode:  405 / score :  360.0
# episode:  406 / score :  467.0
# episode:  407 / score :  901.0
# episode:  408 / score :  1310.0
# episode:  409 / score :  208.0
# episode:  410 / score :  2000.0
# episode:  411 / score :  466.0
# episode:  412 / score :  807.0
# episode:  413 / score :  414.0
# episode:  414 / score :  301.0
# episode:  415 / score :  584.0
# episode:  416 / score :  715.0
# episode:  417 / score :  1645.0
# episode:  418 / score :  340.0
# episode:  419 / score :  323.0
# episode:  420 / score :  1352.0
# episode:  421 / score :  1517.0
# episode:  422 / score :  484.0
# episode:  423 / score :  1837.0
# episode:  424 / score :  1135.0
# episode:  425 / score :  234.0
# episode:  426 / score :  454.0
# episode:  427 / score :  431.0
# episode:  428 / score :  350.0
# episode:  429 / score :  644.0
# episode:  430 / score :  795.0
# episode: episode:  431 / score :  202.0
#  432 / score :  356.0
# episode:  433 / score :  1399.0
# episode:  434 / score :  638.0
# episode:  435 / score :  1033.0
# episode:  436 / score :  712.0
# episode:  437 / score :  1763.0
# episode:  438 / score :  689.0
# episode:  439 / score :  707.0
# episode:  440 / score :  838.0
# episode:  441 / score :  443.0
# episode:  442 / score :  1037.0
# episode:  443 / score :  282.0
# episode:  444 / score :  1322.0
# episode:  445 / score :  1044.0
# episode:  446 / score :  2000.0
# episode:  447 / score :  1236.0
# episode:  448 / score :  1288.0
# episode:  449 / score :  544.0
# episode:  450 / score :  2000.0
# episode:  451 / score :  1523.0
# episode:  452 / score :  2000.0
# episode:  453 / score :  2000.0
# episode:  454 / score :  2000.0
# episode:  455 / score :  393.0
# episode:  456 / score :  2000.0
# episode:  457 / score :  2000.0
# episode:  458 / score :  989.0
# episode:  459 / score :  2000.0
# episode:  460 / score :  1512.0
# episode:  461 / score :  1040.0
# episode:  462 / score :  2000.0
# episode:  463 / score :  2000.0
# episode:  464 / score :  809.0
# episode:  465 / score :  2000.0
# episode:  466 / score :  2000.0
# episode:  467 / score :  2000.0
# episode:  468 / score :  874.0
# episode:  469 / score :  2000.0
# episode:  470 / score :  2000.0
# episode:  471 / score :  1903.0
# episode:  472 / score :  2000.0
# episode:  473 / score :  153.0
# episode:  474 / score :  910.0
# episode:  475 / score :  894.0
# episode:  476 / score :  1875.0
# episode:  477 / score :  2000.0
# episode:  478 / score :  2000.0
# episode:  479 / score :  2000.0
# episode:  480 / score :  662.0
# episode:  481 / score :  2000.0
# episode:  482 / score :  2000.0
# episode:  483 / score :  1909.0
# episode:  484 / score :  834.0
# episode:  episode:  486 485 / score :  2000.0
# / score :  2000.0
# episode:  487 / score :  2000.0
# episode:  488 / score :  2000.0
# episode:  489 / score :  2000.0
# episode:  490 / score :  2000.0
# episode:  491 / score :  2000.0
# episode:  492 / score :  2000.0
# episode:  493 / score :  534.0
# episode:  494 / score :  1428.0
# episode:  495 / score :  1838.0
# episode:  496 / score :  2000.0
# episode:  497 / score :  2000.0
# episode:  498 / score :  576.0
# episode:  499 / score :  2000.0
# episode:  500 / score :  1125.0
# episode:  501 / score :  2000.0
# episode:  502 / score :  828.0
# episode:  503 / score :  492.0
# episode:  504 / score :  787.0
# episode:  505 / score :  1254.0
# episode:  506 / score :  1072.0
# episode:  507 / score :  742.0
# episode:  508 / score :  2000.0
# episode:  509 / score :  2000.0
# episode:  510 / score :  2000.0
# episode:  511 / score :  669.0
# episode:  512 / score :  2000.0
# episode:  513 / score :  177.0
# episode:  514 / score :  2000.0
# episode:  515 / score :  2000.0
# episode:  516 / score :  2000.0
# episode:  517 / score :  1054.0
# episode:  518 / score :  2000.0
# episode:  519 / score :  2000.0
# episode:  520 / score :  2000.0
# episode:  521 / score :  2000.0
# episode:  522 / score :  2000.0
# episode:  523 / score :  2000.0
# episode:  524 / score :  2000.0
# episode:  525 / score :  2000.0
# episode:  526 / score :  2000.0
# episode:  527 / score :  2000.0
# episode:  528 / score :  2000.0
# episode:  529 / score :  2000.0
# episode:  530 / score :  2000.0
# episode:  531 / score :  2000.0
# episode:  532 / score :  2000.0
# episode:  533 / score :  2000.0
# episode:  534 / score :  2000.0
# episode:  535 / score :  2000.0
# episode:  536 / score :  2000.0
# episode: episode:   538 / score :  2000.0
# 537 / score :  2000.0
# episode:  539 / score :  2000.0
# episode:  540 / score :  2000.0
# episode:  541 / score :  2000.0
# episode:  542 / score :  2000.0
# episode:  543 / score :  2000.0
# episode:  544 / score :  631.0
# episode:  545 / score :  2000.0
# episode:  546 / score :  2000.0
# episode:  547 / score :  2000.0
# episode:  548 / score :  2000.0
# episode:  549 / score :  1726.0
# episode:  550 / score :  2000.0
# episode:  551 / score :  2000.0
# episode:  552 / score :  1343.0
# episode:  553 / score :  2000.0
# episode:  554 / score :  2000.0
# episode:  555 / score :  2000.0
# episode:  556 / score :  2000.0
# episode:  557 / score :  1030.0
# episode:  558 / score :  793.0
# episode: episode:  559 / score :  2000.0 560 / score :  296.0
#
# episode:  561 / score :  918.0
# episode:  562 / score :  1141.0
# episode:  563 / score :  1606.0
# episode:  564 / score :  2000.0
# episode:  565 / score :  2000.0
# episode:  566 / score :  2000.0
# episode:  567 / score :  1182.0
# episode:  568 / score :  2000.0
# episode:  569 / score :  2000.0
# episode:  570 / score :  2000.0
# episode:  571 / score :  2000.0
# episode:  572 / score :  2000.0
# episode:  573 / score :  2000.0
# episode:  574 / score :  2000.0
# episode:  575 / score :  321.0
# episode:  576 / score :  1808.0
# episode:  577 / score :  2000.0
# episode:  578 / score :  2000.0
# episode:  579 / score :  1519.0
# episode:  580 / score :  2000.0
# episode:  581 / score :  1034.0
# episode:  582 / score :  2000.0
# episode:  583 / score :  2000.0
# episode:  584 / score :  1730.0
# episode:  585 / score :  2000.0
# episode:  586 / score :  2000.0
# episode:  587 / score :  2000.0
# episode:  588 / score :  2000.0
# episode:  589 / score :  246.0
# episode:  590 / score :  2000.0
# episode:  591 / score :  2000.0
# episode:  592 / score :  2000.0
# episode:  593 / score :  2000.0
# episode:  594 / score :  2000.0
# episode:  595 / score :  2000.0
# episode:  596 / score :  2000.0
# episode:  597 / score :  2000.0
# episode:  598 / score :  2000.0
# episode:  599 / score :  1141.0
# episode:  600 / score :  2000.0
# episode:  601 / score :  1581.0
# episode:  602 / score :  2000.0
# episode:  603 / score :  2000.0
# episode:  604 / score :  2000.0
# episode:  605 / score :  2000.0
# episode:  606 / score :  2000.0
# episode:  607 / score :  2000.0
# episode:  608 / score :  2000.0
# episode:  609 / score :  2000.0
# episode:  610 / score :  2000.0
# episode:  611 / score :  2000.0
# episode:  612 / score :  2000.0
# episode:  613 / score :  2000.0
# episode:  614 / score :  147.0
# episode:  615 / score :  2000.0
# episode:  616 / score :  2000.0
# episode:  617 / score :  772.0
# episode:  618 / score :  1432.0
# episode:  619 / score :  2000.0
# episode:  620 / score :  2000.0
# episode:  621 / score :  2000.0
# episode:  622 / score :  2000.0
# episode:  623 / score :  2000.0
# episode:  624episode:  / score :  2000.0
#  625 / score :  2000.0
# episode:  626 / score :  2000.0
# episode:  627 / score :  2000.0
# episode:  628 / score :  2000.0
# episode:  629 / score :  2000.0
# episode:  630 / score :  1824.0
# episode:  631 / score :  2000.0
# episode:  632episode:  633 / score :  2000.0
#  / score :  2000.0
# episode:  634 / score :  2000.0
# episode:  635 / score :  2000.0
# episode:  636 / score :  2000.0
# episode:  637 / score :  2000.0
# episode:  638 / score :  2000.0
# episode:  639 / score :  2000.0
# episode:  640 / score :  2000.0
# episode:  641 / score :  2000.0
# episode:  642 / score :  2000.0
# episode:  643 / score :  2000.0
# episode:  644 / score :  2000.0
# episode:  645 / score :  2000.0
# episode:  646 / score :  2000.0
# episode:  647 / score :  2000.0
# episode:  648 / score :  2000.0
# episode:  649 / score :  2000.0
# episode:  650 / score :  2000.0
# episode:  651 / score :  2000.0
# episode:  652 / score :  2000.0
# episode:  653 / score :  2000.0
# episode:  654 / score :  2000.0
# episode:  655 / score :  2000.0
# episode:  656 / score :  1975.0
# episode:  657 / score :  2000.0
# episode:  658 / score :  2000.0
# episode:  659 / score :  2000.0
# episode:  660 / score :  2000.0
# episode:  661 / score :  2000.0
# episode:  662 / score :  2000.0
# episode:  663 / score :  2000.0
# episode:  664 / score :  194.0
# episode:  665 / score :  346.0
# episode:  666 / score :  1266.0
# episode:  667 / score :  2000.0
# episode:  668 / score :  2000.0
# episode:  669 / score :  2000.0
# episode:  670 / score :  2000.0
# episode:  671 / score :  2000.0
# episode:  672 / score :  2000.0
# episode:  673 / score :  2000.0
# episode:  674 / score :  2000.0
# episode:  675 / score :  211.0
# episode:  676 / score :  2000.0
# episode:  677 / score :  2000.0
# episode:  678 / score :  2000.0
# episode:  679 / score :  2000.0
# episode:  680 / score :  2000.0
# episode:  681 / score :  2000.0
# episode:  682 / score :  2000.0
# episode:  683 / score :  2000.0
# episode:  684 / score :  2000.0
# episode:  685 / score :  2000.0
# episode:  686 / score :  2000.0
# episode:  687 / score :  2000.0
# episode:  688 / score :  2000.0
# episode:  689 / score :  2000.0
# episode:  690 / score :  2000.0
# episode:  691 / score :  2000.0
# episode:  692 / score :  2000.0
# episode:  693 / score :  2000.0
# episode:  694 / score :  2000.0
# episode:  695 / score :  2000.0
# episode:  696 / score :  2000.0
# episode:  697 / score :  2000.0
# episode:  698 / score :  2000.0
# episode:  699 / score :  2000.0
