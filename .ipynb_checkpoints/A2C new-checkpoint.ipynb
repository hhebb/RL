# %% [markdown]
# # A2C(Cart Pole)
# ---
#
# * https://github.com/rlcode/reinforcement-learning/tree/master/2-cartpole/4-actor-critic 참고함

# %%
import sys
import gym
import pylab
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
EPISODES = 1000

# %%
# A2C(Advantage Actor-Critic) agent for the Cartpole
class A2CAgent:
    def __init__(self, state_size, action_size):
        # if you want to see Cartpole learning, then change to True
        self.render = False
        self.load_model = False
        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size
        self.value_size = 1

        # These are hyper parameters for the Policy Gradient
        self.discount_factor = 0.99
        self.actor_lr = 0.001
        self.critic_lr = 0.005

        # create model for policy network
        self.actor = self.build_actor()
        self.critic = self.build_critic()

    # approximate policy and value using Neural Network
    # actor: state is input and probability of each action is output of model
    def build_actor(self):
        actor = Sequential()
        actor.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        actor.add(Dense(self.action_size, activation='softmax',
                        kernel_initializer='he_uniform'))
        actor.summary()
        # See note regarding crossentropy in cartpole_reinforce.py
        actor.compile(loss='categorical_crossentropy',
                      optimizer=Adam(lr=self.actor_lr))
        return actor

    # critic: state is input and value of state is output of model
    def build_critic(self):
        critic = Sequential()
        critic.add(Dense(24, input_dim=self.state_size, activation='relu',
                         kernel_initializer='he_uniform'))
        critic.add(Dense(self.value_size, activation='linear',
                         kernel_initializer='he_uniform'))
        critic.summary()
        critic.compile(loss="mse", optimizer=Adam(lr=self.critic_lr))
        return critic

    # using the output of policy network, pick action stochastically
    def get_action(self, state):
        policy = self.actor.predict(state, batch_size=1).flatten()
        return np.random.choice(self.action_size, 1, p=policy)[0]

    # update policy network every episode
    def train_model(self, state, action, reward, next_state, done):
        target = np.zeros((1, self.value_size))
        advantages = np.zeros((1, self.action_size))

        value = self.critic.predict(state)[0]
        next_value = self.critic.predict(next_state)[0]

        if done:
            advantages[0][action] = reward - value
            target[0][0] = reward
        else:
            advantages[0][action] = reward + self.discount_factor * (next_value) - value
            target[0][0] = reward + self.discount_factor * next_value

        self.actor.fit(state, advantages, epochs=1, verbose=0)
        self.critic.fit(state, target, epochs=1, verbose=0)

# %%
if __name__ == "__main__":
    # In case of CartPole-v1, maximum length of episode is 500
    env = gym.make('CartPole-v1')
    # get size of state and action from environment
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # make A2C agent
    agent = A2CAgent(state_size, action_size)

    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            action = agent.get_action(state)
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            # if an action make the episode end, then gives penalty of -100
            reward = reward if not done or score == 499 else -100

            agent.train_model(state, action, reward, next_state, done)

            score += reward
            state = next_state

            if done:
                # every episode, plot the play time
                score = score if score == 500.0 else score + 100
                scores.append(score)
                episodes.append(e)
                #pylab.plot(episodes, scores, 'b')
                #pylab.savefig("./save_graph/cartpole_a2c.png")
                print("episode:", e, "  score:", score)

                # if the mean of scores of last 10 episode is bigger than 490
                # stop training
                if np.mean(scores[-min(10, len(scores)):]) > 490:
                    sys.exit()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 170
# Trainable params: 170
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 25
# =================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0   score: 22.0
# episode: 1   score: 11.0
# episode: 2   score: 7.0
# episode: 3   score: 9.0
# episode: 4   score: 35.0
# episode: 5   score: 15.0
# episode: 6   score: 12.0
# episode: 7   score: 8.0
# episode: 8   score: 12.0
# episode: 9   score: 15.0
# episode: 10   score: 14.0
# episode: 11   score: 18.0
# episode: 12   score: 12.0
# episode: 13   score: 8.0
# episode: 14   score: 10.0
# episode: 15   score: 8.0
# episode: 16   score: 10.0
# episode: 17   score: 14.0
# episode: 18   score: 20.0
# episode: 19   score: 30.0
# episode: 20   score: 8.0
# episode: 21   score: 23.0
# episode: 22   score: 18.0
# episode: 23   score: 8.0
# episode: 24   score: 14.0
# episode: 25   score: 9.0
# episode: 26   score: 14.0
# episode: 27   score: 16.0
# episode: 28   score: 21.0
# episode: 29   score: 24.0
# episode: 30   score: 18.0
# episode: 31   score: 18.0
# episode: 32   score: 8.0
# episode: 33   score: 10.0
# episode: 34   score: 19.0
# episode: 35   score: 11.0
# episode: 36   score: 14.0
# episode: 37   score: 9.0
# episode: 38   score: 20.0
# episode: 39   score: 20.0
# episode: 40   score: 11.0
# episode: 41   score: 14.0
# episode: 42   score: 12.0
# episode: 43   score: 9.0
# episode: 44   score: 10.0
# episode: 45   score: 15.0
# episode: 46   score: 9.0
# episode: 47   score: 27.0
# episode: 48   score: 15.0
# episode: 49   score: 14.0
# episode: 50   score: 11.0
# episode: 51   score: 8.0
# episode: 52   score: 10.0
# episode: 53   score: 10.0
# episode: 54   score: 20.0
# episode: 55   score: 41.0
# episode: 56   score: 22.0
# episode: 57   score: 9.0
# episode: 58   score: 27.0
# episode: 59   score: 14.0
# episode: 60   score: 19.0
# episode: 61   score: 9.0
# episode: 62   score: 9.0
# episode: 63   score: 14.0
# episode: 64   score: 13.0
# episode: 65   score: 11.0
# episode: 66   score: 10.0
# episode: 67   score: 15.0
# episode: 68   score: 15.0
# episode: 69   score: 9.0
# episode: 70   score: 10.0
# episode: 71   score: 19.0
# episode: 72   score: 29.0
# episode: 73   score: 28.0
# episode: 74   score: 12.0
# episode: 75   score: 37.0
# episode: 76   score: 9.0
# episode: 77   score: 12.0
# episode: 78   score: 18.0
# episode: 79   score: 29.0
# episode: 80   score: 23.0
# episode: 81   score: 14.0
# episode: 82   score: 12.0
# episode: 83   score: 28.0
# episode: 84   score: 19.0
# episode: 85   score: 54.0
# episode: 86   score: 28.0
# episode: 87   score: 39.0
# episode: 88   score: 120.0
# episode: 89   score: 107.0
# episode: 90   score: 45.0
# episode: 91   score: 114.0
# episode: 92   score: 41.0
# episode: 93   score: 44.0
# episode: 94   score: 35.0
# episode: 95   score: 41.0
# episode: 96   score: 46.0
# episode: 97   score: 95.0
# episode: 98   score: 43.0
# episode: 99   score: 40.0
# episode: 100   score: 55.0
# episode: 101   score: 51.0
# episode: 102   score: 84.0
# episode: 103   score: 36.0
# episode: 104   score: 75.0
# episode: 105   score: 83.0
# episode: 106   score: 44.0
# episode: 107   score: 34.0
# episode: 108   score: 64.0
# episode: 109   score: 47.0
# episode: 110   score: 121.0
# episode: 111   score: 60.0
# episode: 112   score: 54.0
# episode: 113   score: 42.0
# episode: 114   score: 61.0
# episode: 115   score: 69.0
# episode: 116   score: 47.0
# episode: 117   score: 70.0
# episode: 118   score: 56.0
# episode: 119   score: 66.0
# episode: 120   score: 35.0
# episode: 121   score: 60.0
# episode: 122   score: 70.0
# episode: 123   score: 58.0
# episode: 124   score: 59.0
# episode: 125   score: 71.0
# episode: 126   score: 62.0
# episode: 127   score: 67.0
# episode: 128   score: 76.0
# episode: 129   score: 49.0
# episode: 130   score: 66.0
# episode: 131   score: 53.0
# episode: 132   score: 71.0
# episode: 133   score: 38.0
# episode: 134   score: 79.0
# episode: 135   score: 67.0
# episode: 136   score: 140.0
# episode: 137   score: 69.0
# episode: 138   score: 222.0
# episode: 139   score: 96.0
# episode: 140   score: 45.0
# episode: 141   score: 53.0
# episode: 142   score: 112.0
# episode: 143   score: 116.0
# episode: 144   score: 151.0
# episode: 145   score: 100.0
# episode: 146   score: 48.0
# episode: 147   score: 67.0
# episode: 148   score: 119.0
# episode: 149   score: 68.0
# episode: 150   score: 168.0
# episode: 151   score: 275.0
# episode: 152   score: 183.0
# episode: 153   score: 182.0
# episode: 154   score: 80.0
# episode: 155   score: 139.0
# episode: 156   score: 132.0
# episode: 157   score: 111.0
# episode: 158   score: 66.0
# episode: 159   score: 105.0
# episode: 160   score: 104.0
# episode: 161   score: 134.0
# episode: 162   score: 186.0
# episode: 163   score: 88.0
# episode: 164   score: 198.0
# episode: 165   score: 103.0
# episode: 166   score: 110.0
# episode: 167   score: 89.0
# episode: 168   score: 111.0
# episode: 169   score: 62.0
# episode: 170   score: 94.0
# episode: 171   score: 57.0
# episode: 172   score: 83.0
# episode: 173   score: 92.0
# episode: 174   score: 110.0
# episode: 175   score: 56.0
# episode: 176   score: 108.0
# episode: 177   score: 97.0
# episode: 178   score: 86.0
# episode: 179   score: 76.0
# episode: 180   score: 107.0
# episode: 181   score: 129.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3a16c0d76e4b> in <module>
#      27             reward = reward if not done or score == 499 else -100
#      28
# ---> 29             agent.train_model(state, action, reward, next_state, done)
#      30
#      31             score += reward
#
# <ipython-input-3-8e47cbe3852b> in train_model(self, state, action, reward, next_state, done)
#      69             target[0][0] = reward + self.discount_factor * next_value
#      70
# ---> 71         self.actor.fit(state, advantages, epochs=1, verbose=0)
#      72         self.critic.fit(state, target, epochs=1, verbose=0)
#
# C:\Anaconda\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# C:\Anaconda\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# C:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# C:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
