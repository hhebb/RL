# %% [markdown]
# # A2C (Advantage Actor Critic)
# ---
# ## 환경
# * state : discrete[16]
# * action : discrete[4]
# * 목표에 도달 시 +1 점, 구멍에 빠질 때 -1 점, 나머지 0 점.
#
# ## 환경
# * input : state (array[16])
# * output : Q (prob)
# ---
# * A2C 알고리즘은 Critic 을 도입한 Policy Gradient 알고리즘이다
# * 기본적으로 on-policy 알고리즘이기 때문에 자기상관도에 의해 성능이 떨어진다.
# * 이는 A3C 나 다른 off-policy 기법(Importance Sampling)을 사용해야 한다.

# %%
import numpy as np
import tensorflow as tf
import gym
from gym.envs.registration import register
from keras.layers import Dense
from keras.models import Sequential
from keras import backend as K
from keras.optimizers import Adam
import random
# Out:
# Using TensorFlow backend.

# %%
'''
환경 생성
'''
env = gym.make('CartPole-v1')

# %%
save_file = 'C:\\Users\\김민수\\Documents\\GitHub\\RL\\vars\\cartpole_pg'
lr = .002 ## learning rate
total_episode = 1000
epsilon = 1
gamma = .95  ##Discounted factor

# %%
# Actor Network
size_in = env.observation_space.shape[0]
size_out = env.action_space.n
size_w1 = 16
size_w2 = 24
size_w3 = 12

Advantage = tf.placeholder(tf.float32)
STATE_IN = tf.placeholder(tf.float32, [None, size_in])
A_1 = tf.Variable(tf.random_normal([size_in, size_w1],stddev=.01), name='A_1')
A_2 = tf.Variable(tf.random_normal([size_w1, size_w2],stddev=.01), name='A_2')
A_3 = tf.Variable(tf.random_normal([size_w2, size_w3],stddev=.01), name='A_3')
out = tf.Variable(tf.random_normal([size_w3, size_out],stddev=.01), name='out')

L_1 = (tf.matmul(STATE_IN, A_1))
L_2 = (tf.matmul(L_1, A_2))
L_3 = (tf.matmul(L_2, A_3))
L_out = tf.sigmoid(tf.matmul(L_3, out))

loss = -tf.reduce_mean(tf.log(L_out) * Advantage)
train = tf.train.AdamOptimizer(lr).minimize(loss)

# %%
# Critic Network
# 출력은 single 실수값 value
targetV = tf.placeholder(tf.float32)
STATE_IN_c = tf.placeholder(tf.float32, [None, size_in])
C_1 = tf.Variable(tf.random_normal([size_in, size_w1],stddev=.01), name='C_1')
C_2 = tf.Variable(tf.random_normal([size_w1, size_w2],stddev=.01), name='C_2')
C_3 = tf.Variable(tf.random_normal([size_w2, size_w3],stddev=.01), name='C_3')
out_c = tf.Variable(tf.random_normal([size_w3, 1],stddev=.01), name='out')

Lc_1 = (tf.matmul(STATE_IN_c, C_1))
Lc_2 = (tf.matmul(Lc_1, C_2))
Lc_3 = (tf.matmul(Lc_2, C_3))
Lc_out = tf.sigmoid(tf.matmul(Lc_3, out_c))

loss_c = tf.reduce_mean(tf.square(Lc_out - targetV))
train_c = tf.train.AdamOptimizer(lr).minimize(loss_c)

# %%
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    state = env.reset()
    ep = 1
    step = 0
    total_reward = 0
    
    while ep < total_episode:
        step += 1
        #env.render()
        state = np.reshape(state, newshape=[1, size_in])
        Q_prev = sess.run(L_out, feed_dict={STATE_IN:state})
        
        # actor 로 액션선택
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(Q_prev)
            
        new_state, r, d, _ = env.step(action)
        new_state = np.reshape(new_state, newshape=[1, size_in])
        
        # value 계산
        value = sess.run(Lc_out, feed_dict={STATE_IN_c:state})[0][0]
        value_next = sess.run(Lc_out, feed_dict={STATE_IN_c:new_state})[0][0]
        
        # 도중에 쓰러지면 punish
        if d:
            advantage = -100
            target = -100        # - 보상(벌) 을 주어서 그 액션은 하지 않도록 강화한다.
            epsilon = 1 / ((ep/100) + 2)
            print("episode {}, score : {} ".format(ep, step))
            step = 0
            ep += 1
            state = env.reset()
        # advantage 와 targetV 계산
        else:
            target = r + gamma * value_next
            advantage = r + gamma * value_next - value            
            state = new_state
        
        if(np.shape(state) != (1, 4)):
            state = np.reshape(state, newshape=[1, size_in])
        
        # Actor 와 Critic 함께 학습.
        sess.run(train, feed_dict={STATE_IN:state, Advantage:advantage})
        sess.run(train_c, feed_dict={STATE_IN_c:state, targetV:target})
            
env.close()
# Out:
# episode 1, score : 86
# episode 2, score : 33
# episode 3, score : 22
# episode 4, score : 20
# episode 5, score : 13
# episode 6, score : 21
# episode 7, score : 25
# episode 8, score : 27
# episode 9, score : 44
# episode 10, score : 29
# episode 11, score : 31
# episode 12, score : 17
# episode 13, score : 43
# episode 14, score : 43
# episode 15, score : 31
# episode 16, score : 38
# episode 17, score : 35
# episode 18, score : 47
# episode 19, score : 36
# episode 20, score : 33
# episode 21, score : 47
# episode 22, score : 37
# episode 23, score : 104
# episode 24, score : 70
# episode 25, score : 73
# episode 26, score : 88
# episode 27, score : 33
# episode 28, score : 77
# episode 29, score : 35
# episode 30, score : 77
# episode 31, score : 31
# episode 32, score : 14
# episode 33, score : 11
# episode 34, score : 33
# episode 35, score : 42
# episode 36, score : 9
# episode 37, score : 10
# episode 38, score : 11
# episode 39, score : 11
# episode 40, score : 12
# episode 41, score : 11
# episode 42, score : 14
# episode 43, score : 28
# episode 44, score : 34
# episode 45, score : 24
# episode 46, score : 10
# episode 47, score : 33
# episode 48, score : 12
# episode 49, score : 11
# episode 50, score : 16
# episode 51, score : 10
# episode 52, score : 14
# episode 53, score : 11
# episode 54, score : 11
# episode 55, score : 12
# episode 56, score : 40
# episode 57, score : 10
# episode 58, score : 28
# episode 59, score : 54
# episode 60, score : 83
# episode 61, score : 10
# episode 62, score : 12
# episode 63, score : 150
# episode 64, score : 20
# episode 65, score : 91
# episode 66, score : 200
# episode 67, score : 119
# episode 68, score : 64
# episode 69, score : 114
# episode 70, score : 391
# episode 71, score : 146
# episode 72, score : 85
# episode 73, score : 275
# episode 74, score : 135
# episode 75, score : 78
# episode 76, score : 27
# episode 77, score : 46
# episode 78, score : 47
# episode 79, score : 94
# episode 80, score : 117
# episode 81, score : 12
# episode 82, score : 24
# episode 83, score : 52
# episode 84, score : 164
# episode 85, score : 15
# episode 86, score : 25
# episode 87, score : 14
# episode 88, score : 28
# episode 89, score : 25
# episode 90, score : 12
# episode 91, score : 15
# episode 92, score : 12
# episode 93, score : 15
# episode 94, score : 25
# episode 95, score : 13
# episode 96, score : 19
# episode 97, score : 14
# episode 98, score : 13
# episode 99, score : 25
# episode 100, score : 25
# episode 101, score : 10
# episode 102, score : 10
# episode 103, score : 33
# episode 104, score : 16
# episode 105, score : 15
# episode 106, score : 12
# episode 107, score : 27
# episode 108, score : 23
# episode 109, score : 17
# episode 110, score : 25
# episode 111, score : 10
# episode 112, score : 19
# episode 113, score : 10
# episode 114, score : 14
# episode 115, score : 13
# episode 116, score : 12
# episode 117, score : 11
# episode 118, score : 12
# episode 119, score : 19
# episode 120, score : 14
# episode 121, score : 9
# episode 122, score : 16
# episode 123, score : 12
# episode 124, score : 11
# episode 125, score : 9
# episode 126, score : 10
# episode 127, score : 11
# episode 128, score : 12
# episode 129, score : 9
# episode 130, score : 11
# episode 131, score : 12
# episode 132, score : 12
# episode 133, score : 11
# episode 134, score : 10
# episode 135, score : 11
# episode 136, score : 10
# episode 137, score : 11
# episode 138, score : 9
# episode 139, score : 14
# episode 140, score : 13
# episode 141, score : 13
# episode 142, score : 12
# episode 143, score : 11
# episode 144, score : 11
# episode 145, score : 13
# episode 146, score : 9
# episode 147, score : 23
# episode 148, score : 12
# episode 149, score : 12
# episode 150, score : 11
# episode 151, score : 11
# episode 152, score : 12
# episode 153, score : 11
# episode 154, score : 10
# episode 155, score : 13
# episode 156, score : 10
# episode 157, score : 11
# episode 158, score : 11
# episode 159, score : 12
# episode 160, score : 12
# episode 161, score : 12
# episode 162, score : 10
# episode 163, score : 12
# episode 164, score : 14
# episode 165, score : 10
# episode 166, score : 10
# episode 167, score : 11
# episode 168, score : 12
# episode 169, score : 12
# episode 170, score : 11
# episode 171, score : 11
# episode 172, score : 9
# episode 173, score : 12
# episode 174, score : 14
# episode 175, score : 11
# episode 176, score : 12
# episode 177, score : 10
# episode 178, score : 10
# episode 179, score : 18
# episode 180, score : 10
# episode 181, score : 11
# episode 182, score : 12
# episode 183, score : 12
# episode 184, score : 11
# episode 185, score : 10
# episode 186, score : 11
# episode 187, score : 10
# episode 188, score : 11
# episode 189, score : 10
# episode 190, score : 9
# episode 191, score : 10
# episode 192, score : 10
# episode 193, score : 9
# episode 194, score : 11
# episode 195, score : 10
# episode 196, score : 11
# episode 197, score : 10
# episode 198, score : 10
# episode 199, score : 14
# episode 200, score : 10
# episode 201, score : 12
# episode 202, score : 13
# episode 203, score : 9
# episode 204, score : 16
# episode 205, score : 10
# episode 206, score : 9
# episode 207, score : 10
# episode 208, score : 12
# episode 209, score : 11
# episode 210, score : 9
# episode 211, score : 10
# episode 212, score : 11
# episode 213, score : 10
# episode 214, score : 11
# episode 215, score : 9
# episode 216, score : 11
# episode 217, score : 11
# episode 218, score : 10
# episode 219, score : 10
# episode 220, score : 9
# episode 221, score : 12
# episode 222, score : 10
# episode 223, score : 10
# episode 224, score : 11
# episode 225, score : 10
# episode 226, score : 14
# episode 227, score : 12
# episode 228, score : 11
# episode 229, score : 11
# episode 230, score : 12
# episode 231, score : 10
# episode 232, score : 10
# episode 233, score : 10
# episode 234, score : 12
# episode 235, score : 9
# episode 236, score : 13
# episode 237, score : 9
# episode 238, score : 11
# episode 239, score : 10
# episode 240, score : 10
# episode 241, score : 11
# episode 242, score : 10
# episode 243, score : 11
# episode 244, score : 10
# episode 245, score : 10
# episode 246, score : 10
# episode 247, score : 16
# episode 248, score : 9
# episode 249, score : 10
# episode 250, score : 10
# episode 251, score : 9
# episode 252, score : 9
# episode 253, score : 11
# episode 254, score : 11
# episode 255, score : 10
# episode 256, score : 11
# episode 257, score : 11
# episode 258, score : 10
# episode 259, score : 11
# episode 260, score : 9
# episode 261, score : 15
# episode 262, score : 11
# episode 263, score : 12
# episode 264, score : 13
# episode 265, score : 10
# episode 266, score : 10
# episode 267, score : 11
# episode 268, score : 8
# episode 269, score : 11
# episode 270, score : 14
# episode 271, score : 10
# episode 272, score : 10
# episode 273, score : 10
# episode 274, score : 9
# episode 275, score : 14
# episode 276, score : 10
# episode 277, score : 8
# episode 278, score : 10
# episode 279, score : 11
# episode 280, score : 10
# episode 281, score : 10
# episode 282, score : 15
# episode 283, score : 10
# episode 284, score : 11
# episode 285, score : 11
# episode 286, score : 10
# episode 287, score : 8
# episode 288, score : 8
# episode 289, score : 10
# episode 290, score : 11
# episode 291, score : 17
# episode 292, score : 13
# episode 293, score : 10
# episode 294, score : 10
# episode 295, score : 9
# episode 296, score : 12
# episode 297, score : 11
# episode 298, score : 10
# episode 299, score : 10
# episode 300, score : 9
# episode 301, score : 12
# episode 302, score : 9
# episode 303, score : 12
# episode 304, score : 10
# episode 305, score : 9
# episode 306, score : 12
# episode 307, score : 10
# episode 308, score : 10
# episode 309, score : 12
# episode 310, score : 11
# episode 311, score : 9
# episode 312, score : 11
# episode 313, score : 10
# episode 314, score : 10
# episode 315, score : 10
# episode 316, score : 13
# episode 317, score : 10
# episode 318, score : 14
# episode 319, score : 11
# episode 320, score : 11
# episode 321, score : 11
# episode 322, score : 10
# episode 323, score : 14
# episode 324, score : 11
# episode 325, score : 9
# episode 326, score : 10
# episode 327, score : 8
# episode 328, score : 14
# episode 329, score : 19
# episode 330, score : 8
# episode 331, score : 9
# episode 332, score : 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-3f3389269d61> in <module>
#      44
#      45         sess.run(train, feed_dict={STATE_IN:state, Advantage:advantage})
# ---> 46         sess.run(train_c, feed_dict={STATE_IN_c:state, targetV:target})
#      47
#      48 env.close()
#
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# C:\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
