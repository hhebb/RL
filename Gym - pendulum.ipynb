# %% [markdown]
# # Pendulum
# ---
# >action 과 state 가 모두 continuous 한 환경이다. 목표는 막대를 수직으로 오래 유지하는 것이다. 종료조건은 따로 없다. 최대 시간을 두는 것이 좋을 수도 있다.
#
#
# * state : 막대의 sin, cos, 각속도
# * action : 조인트에 작용하는 -2 ~ 2 사이 토크
# * reward : -(theta^2 + 0.1*theta_dt^2 + 0.001*action^2)
# ---

# %%
import tensorflow as tf
import numpy as np
import gym
import random
from collections import deque
import dqn

# %%
'''
환경 생성
'''
env = gym.make('Pendulum-v0')

# %%
size_s = env.observation_space.shape[0]
size_out = env.action_space.shape[0]
gamma = .95
print(size_s)
# Out:
# 3

# %%
'''
학습 네트워크 -> target 네트워크 로 복사하는 함수
''' 
def copy(*, dest_scope_name = 'target', src_scope_name = 'main') :
    op_holder = []
    
    src_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope = src_scope_name)
    dest_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope = dest_scope_name)
    
    for src_var, dest_var in zip(src_vars, dest_vars) :
        op_holder.append(dest_var.assign(src_var))
        
    return op_holder

# %%
'''
replay experience, 공급된 batch 로 학습
'''
def replay_train(mainDQN, targetDQN, train_batch) :
    x_stack = np.empty(0).reshape(0, size_s)
    y_stack = np.empty(0).reshape(0, size_out)
    
    for state, action, reward, next_state, done in train_batch :
        
        # 현재 Q 는 main 네트워크에서 도출
        Q = mainDQN.predict(state)
        
        # terminal step 이면 음의 보상
        if done :
            Q[0, action] = -100
        
        # target Q 는 target 네트워크에서 도출 - 자기상관도 감소 (Double Q 러닝 기법이 포함된듯)
        else :
            Q[0, action] = reward + gamma*np.max(targetDQN.predict(next_state))
        
        # x 는 현재 Q
        # y 는 target
        x_stack = np.vstack([x_stack, state])
        y_stack = np.vstack([y_stack, Q])
        
    return mainDQN.update(x_stack, y_stack)

# %%
total_episode = 1000
replay_buffer = deque()
ep = 0
step = 0
#saver = tf.train.Saver()
#save_file = 'C:\\Users\\김민수\\Documents\\GitHub\\RL\\vars\\cartpole_dqn'
mean_reward = deque()

with tf.Session() as sess:
      
    '''
    - 네트워크 2 개 생성
    - 하나는 실제 학습을 하는 학습 네트워크
    - 다른 하나는 일시적으로 고정되어 학습의 목표가 되는 target 네트워크
    '''
    mainDQN = dqn.DQN(sess, size_s, size_out, 8, 6, name='main')
    targetDQN = dqn.DQN(sess, size_s, size_out, 8, 6, name='target')
    
    tf.global_variables_initializer().run()
    
    # 처음 시작 시 네트워크 복사
    copy_ops = copy(dest_scope_name='targetDQN', src_scope_name='mainDQN')
    sess.run(copy_ops)
    
    state = env.reset()
    
    for episode in range(total_episode) :
        e = 1. / ((episode / 20) + 1)    # 점점 감소하는 explore 
        done = False
        step_count = 0
        state = env.reset()
        
        while not done :
             
            # 액션 선택
            if np.random.rand(1) < e :
                action = env.action_space.sample()
            else :
                action = np.argmax(mainDQN.predict(state))
                    
            next_state, reward, done, _ = env.step(action)
                
            if done : 
                reward = -100
                
                
            # 학습하지않고 임시메모리에 저장한다.
            replay_buffer.append((state, action, reward, next_state, done))
            if(len(replay_buffer) > 50000) :
                replay_buffer.popleft()
            
            state = next_state
            step_count += 1
            
            if(step_count > 1000) :
                break
        
        
        print ('episode : {}, steps : {}'.format(episode, step_count))
                
        '''
        파라미터 로컬에 저장.
        '''
        if(len(mean_reward) < 10):
            mean_reward.append(step_count)
        else:
            mean_reward.popleft()
            
            '''
            if(np.mean(mean_reward) > 800):
                saver.save(sess, save_file)
                break
            '''
                
        # 10 회의 에피소드가 끝나면 임시메모리에서 과거 데이터를 랜덤으로 뽑아 학습한다.
        if(episode % 10 == 1) :
            for _ in range(50) :
                minibacth = random.sample(replay_buffer, 10)
                loss, _ = replay_train(mainDQN, targetDQN, minibacth)
                        
            print('loss :', loss)
            sess.run(copy_ops)   # 목표가 되는 네트워크를 업데이트한다.
                    
    env.close()
# Out:
# episode : 0, steps : 21
# episode : 1, steps : 27
# loss : 445.75748
# episode : 2, steps : 20
# episode : 3, steps : 24
# episode : 4, steps : 16
# episode : 5, steps : 11
# episode : 6, steps : 24
# episode : 7, steps : 14
# episode : 8, steps : 12
# episode : 9, steps : 11
# episode : 10, steps : 10
# episode : 11, steps : 10
# loss : 506.68994
# episode : 12, steps : 35
# episode : 13, steps : 14
# episode : 14, steps : 46
# episode : 15, steps : 28
# episode : 16, steps : 88
# episode : 17, steps : 40
# episode : 18, steps : 31
# episode : 19, steps : 55
# episode : 20, steps : 39
# episode : 21, steps : 53
# loss : 1.3592613
# episode : 22, steps : 12
# episode : 23, steps : 9
# episode : 24, steps : 15
# episode : 25, steps : 10
# episode : 26, steps : 9
# episode : 27, steps : 10
# episode : 28, steps : 9
# episode : 29, steps : 15
# episode : 30, steps : 8
# episode : 31, steps : 10
# loss : 4.49893
# episode : 32, steps : 110
# episode : 33, steps : 68
# episode : 34, steps : 70
# episode : 35, steps : 89
# episode : 36, steps : 145
# episode : 37, steps : 64
# episode : 38, steps : 63
# episode : 39, steps : 138
# episode : 40, steps : 55
# episode : 41, steps : 88
# loss : 1.8749278
# episode : 42, steps : 57
# episode : 43, steps : 74
# episode : 44, steps : 56
# episode : 45, steps : 57
# episode : 46, steps : 53
# episode : 47, steps : 52
# episode : 48, steps : 88
# episode : 49, steps : 45
# episode : 50, steps : 78
# episode : 51, steps : 68
# loss : 1.0135965
# episode : 52, steps : 49
# episode : 53, steps : 43
# episode : 54, steps : 56
# episode : 55, steps : 31
# episode : 56, steps : 47
# episode : 57, steps : 36
# episode : 58, steps : 39
# episode : 59, steps : 45
# episode : 60, steps : 54
# episode : 61, steps : 41
# loss : 2.7366378
# episode : 62, steps : 19
# episode : 63, steps : 31
# episode : 64, steps : 63
# episode : 65, steps : 36
# episode : 66, steps : 32
# episode : 67, steps : 32
# episode : 68, steps : 37
# episode : 69, steps : 37
# episode : 70, steps : 22
# episode : 71, steps : 94
# loss : 3.863742
# episode : 72, steps : 54
# episode : 73, steps : 48
# episode : 74, steps : 42
# episode : 75, steps : 54
# episode : 76, steps : 53
# episode : 77, steps : 54
# episode : 78, steps : 90
# episode : 79, steps : 84
# episode : 80, steps : 55
# episode : 81, steps : 47
# loss : 2.1040895
# episode : 82, steps : 61
# episode : 83, steps : 51
# episode : 84, steps : 194
# episode : 85, steps : 104
# episode : 86, steps : 91
# episode : 87, steps : 120
# episode : 88, steps : 85
# episode : 89, steps : 68
# episode : 90, steps : 79
# episode : 91, steps : 51
# loss : 1.3180727
# episode : 92, steps : 9
# episode : 93, steps : 10
# episode : 94, steps : 12
# episode : 95, steps : 9
# episode : 96, steps : 10
# episode : 97, steps : 11
# episode : 98, steps : 9
# episode : 99, steps : 10
# episode : 100, steps : 10
# episode : 101, steps : 10
# loss : 1.5023468
# episode : 102, steps : 68
# episode : 103, steps : 69
# episode : 104, steps : 41
# episode : 105, steps : 52
# episode : 106, steps : 72
# episode : 107, steps : 58
# episode : 108, steps : 49
# episode : 109, steps : 78
# episode : 110, steps : 43
# episode : 111, steps : 50
# loss : 0.974825
# episode : 112, steps : 10
# episode : 113, steps : 10
# episode : 114, steps : 11
# episode : 115, steps : 9
# episode : 116, steps : 10
# episode : 117, steps : 8
# episode : 118, steps : 13
# episode : 119, steps : 9
# episode : 120, steps : 10
# episode : 121, steps : 10
# loss : 1.2267106
# episode : 122, steps : 12
# episode : 123, steps : 11
# episode : 124, steps : 12
# episode : 125, steps : 45
# episode : 126, steps : 51
# episode : 127, steps : 27
# episode : 128, steps : 19
# episode : 129, steps : 9
# episode : 130, steps : 17
# episode : 131, steps : 21
# loss : 492.61874
# episode : 132, steps : 35
# episode : 133, steps : 38
# episode : 134, steps : 45
# episode : 135, steps : 40
# episode : 136, steps : 51
# episode : 137, steps : 40
# episode : 138, steps : 52
# episode : 139, steps : 60
# episode : 140, steps : 30
# episode : 141, steps : 32
# loss : 1.1053224
# episode : 142, steps : 20
# episode : 143, steps : 9
# episode : 144, steps : 21
# episode : 145, steps : 41
# episode : 146, steps : 21
# episode : 147, steps : 8
# episode : 148, steps : 27
# episode : 149, steps : 22
# episode : 150, steps : 24
# episode : 151, steps : 15
# loss : 502.83456
# episode : 152, steps : 37
# episode : 153, steps : 44
# episode : 154, steps : 60
# episode : 155, steps : 45
# episode : 156, steps : 49
# episode : 157, steps : 60
# episode : 158, steps : 79
# episode : 159, steps : 69
# episode : 160, steps : 71
# episode : 161, steps : 61
# loss : 0.81570894
# episode : 162, steps : 39
# episode : 163, steps : 36
# episode : 164, steps : 26
# episode : 165, steps : 26
# episode : 166, steps : 68
# episode : 167, steps : 29
# episode : 168, steps : 33
# episode : 169, steps : 25
# episode : 170, steps : 24
# episode : 171, steps : 23
# loss : 1.20509
# episode : 172, steps : 35
# episode : 173, steps : 24
# episode : 174, steps : 42
# episode : 175, steps : 32
# episode : 176, steps : 40
# episode : 177, steps : 18
# episode : 178, steps : 29
# episode : 179, steps : 28
# episode : 180, steps : 44
# episode : 181, steps : 29
# loss : 0.6954618
# episode : 182, steps : 93
# episode : 183, steps : 54
# episode : 184, steps : 84
# episode : 185, steps : 51
# episode : 186, steps : 48
# episode : 187, steps : 35
# episode : 188, steps : 61
# episode : 189, steps : 52
# episode : 190, steps : 81
# episode : 191, steps : 91
# loss : 0.9582796
# episode : 192, steps : 43
# episode : 193, steps : 148
# episode : 194, steps : 58
# episode : 195, steps : 45
# episode : 196, steps : 41
# episode : 197, steps : 76
# episode : 198, steps : 76
# episode : 199, steps : 55
# episode : 200, steps : 47
# episode : 201, steps : 157
# loss : 516.03906
# episode : 202, steps : 10
# episode : 203, steps : 10
# episode : 204, steps : 9
# episode : 205, steps : 10
# episode : 206, steps : 9
# episode : 207, steps : 10
# episode : 208, steps : 8
# episode : 209, steps : 9
# episode : 210, steps : 9
# episode : 211, steps : 11
# loss : 2.957889
# episode : 212, steps : 85
# episode : 213, steps : 60
# episode : 214, steps : 51
# episode : 215, steps : 64
# episode : 216, steps : 36
# episode : 217, steps : 51
# episode : 218, steps : 38
# episode : 219, steps : 108
# episode : 220, steps : 43
# episode : 221, steps : 41
# loss : 1.9008125
# episode : 222, steps : 38
# episode : 223, steps : 27
# episode : 224, steps : 26
# episode : 225, steps : 30
# episode : 226, steps : 28
# episode : 227, steps : 43
# episode : 228, steps : 22
# episode : 229, steps : 49
# episode : 230, steps : 29
# episode : 231, steps : 62
# loss : 1.2582393
# episode : 232, steps : 74
# episode : 233, steps : 40
# episode : 234, steps : 33
# episode : 235, steps : 35
# episode : 236, steps : 42
# episode : 237, steps : 129
# episode : 238, steps : 53
# episode : 239, steps : 45
# episode : 240, steps : 42
# episode : 241, steps : 36
# loss : 1.654136
# episode : 242, steps : 99
# episode : 243, steps : 41
# episode : 244, steps : 65
# episode : 245, steps : 76
# episode : 246, steps : 136
# episode : 247, steps : 41
# episode : 248, steps : 99
# episode : 249, steps : 53
# episode : 250, steps : 31
# episode : 251, steps : 102
# loss : 0.709726
# episode : 252, steps : 35
# episode : 253, steps : 44
# episode : 254, steps : 33
# episode : 255, steps : 47
# episode : 256, steps : 39
# episode : 257, steps : 29
# episode : 258, steps : 35
# episode : 259, steps : 99
# episode : 260, steps : 38
# episode : 261, steps : 55
# loss : 1.5944045
# episode : 262, steps : 25
# episode : 263, steps : 33
# episode : 264, steps : 21
# episode : 265, steps : 40
# episode : 266, steps : 42
# episode : 267, steps : 38
# episode : 268, steps : 32
# episode : 269, steps : 24
# episode : 270, steps : 26
# episode : 271, steps : 22
# loss : 510.04404
# episode : 272, steps : 10
# episode : 273, steps : 9
# episode : 274, steps : 10
# episode : 275, steps : 10
# episode : 276, steps : 11
# episode : 277, steps : 9
# episode : 278, steps : 10
# episode : 279, steps : 9
# episode : 280, steps : 10
# episode : 281, steps : 10
# loss : 1.0484421
# episode : 282, steps : 56
# episode : 283, steps : 41
# episode : 284, steps : 55
# episode : 285, steps : 59
# episode : 286, steps : 56
# episode : 287, steps : 44
# episode : 288, steps : 48
# episode : 289, steps : 19
# episode : 290, steps : 48
# episode : 291, steps : 55
# loss : 2.732418
# episode : 292, steps : 37
# episode : 293, steps : 17
# episode : 294, steps : 13
# episode : 295, steps : 9
# episode : 296, steps : 12
# episode : 297, steps : 22
# episode : 298, steps : 22
# episode : 299, steps : 33
# episode : 300, steps : 9
# episode : 301, steps : 44
# loss : 3.1937509
# episode : 302, steps : 456
# episode : 303, steps : 308
# episode : 304, steps : 182
# episode : 305, steps : 204
# episode : 306, steps : 220
# episode : 307, steps : 395
# episode : 308, steps : 223
# episode : 309, steps : 358
# episode : 310, steps : 214
# episode : 311, steps : 302
# loss : 484.90674
# episode : 312, steps : 200
# episode : 313, steps : 153
# episode : 314, steps : 234
# episode : 315, steps : 271
# episode : 316, steps : 208
# episode : 317, steps : 167
# episode : 318, steps : 177
# episode : 319, steps : 287
# episode : 320, steps : 156
# episode : 321, steps : 126
# loss : 0.9568542
# episode : 322, steps : 39
# episode : 323, steps : 59
# episode : 324, steps : 54
# episode : 325, steps : 63
# episode : 326, steps : 71
# episode : 327, steps : 56
# episode : 328, steps : 64
# episode : 329, steps : 58
# episode : 330, steps : 33
# episode : 331, steps : 63
# loss : 1001.54724
# episode : 332, steps : 50
# episode : 333, steps : 44
# episode : 334, steps : 49
# episode : 335, steps : 29
# episode : 336, steps : 31
# episode : 337, steps : 40
# episode : 338, steps : 41
# episode : 339, steps : 126
# episode : 340, steps : 94
# episode : 341, steps : 110
# loss : 5.057763
# episode : 342, steps : 23
# episode : 343, steps : 26
# episode : 344, steps : 37
# episode : 345, steps : 20
# episode : 346, steps : 24
# episode : 347, steps : 19
# episode : 348, steps : 23
# episode : 349, steps : 17
# episode : 350, steps : 44
# episode : 351, steps : 25
# loss : 1.5130106
# episode : 352, steps : 67
# episode : 353, steps : 63
# episode : 354, steps : 45
# episode : 355, steps : 127
# episode : 356, steps : 95
# episode : 357, steps : 49
# episode : 358, steps : 87
# episode : 359, steps : 129
# episode : 360, steps : 61
# episode : 361, steps : 58
# loss : 2.3949697
# episode : 362, steps : 47
# episode : 363, steps : 45
# episode : 364, steps : 73
# episode : 365, steps : 65
# episode : 366, steps : 152
# episode : 367, steps : 44
# episode : 368, steps : 46
# episode : 369, steps : 56
# episode : 370, steps : 107
# episode : 371, steps : 57
# loss : 478.63275
# episode : 372, steps : 33
# episode : 373, steps : 46
# episode : 374, steps : 69
# episode : 375, steps : 32
# episode : 376, steps : 75
# episode : 377, steps : 62
# episode : 378, steps : 86
# episode : 379, steps : 34
# episode : 380, steps : 52
# episode : 381, steps : 69
# loss : 1.7270372
# episode : 382, steps : 16
# episode : 383, steps : 21
# episode : 384, steps : 25
# episode : 385, steps : 40
# episode : 386, steps : 30
# episode : 387, steps : 45
# episode : 388, steps : 20
# episode : 389, steps : 26
# episode : 390, steps : 29
# episode : 391, steps : 26
# loss : 521.8966
# episode : 392, steps : 22
# episode : 393, steps : 39
# episode : 394, steps : 40
# episode : 395, steps : 36
# episode : 396, steps : 51
# episode : 397, steps : 24
# episode : 398, steps : 26
# episode : 399, steps : 53
# episode : 400, steps : 27
# episode : 401, steps : 20
# loss : 3.9100761
# episode : 402, steps : 46
# episode : 403, steps : 34
# episode : 404, steps : 34
# episode : 405, steps : 28
# episode : 406, steps : 37
# episode : 407, steps : 61
# episode : 408, steps : 48
# episode : 409, steps : 29
# episode : 410, steps : 20
# episode : 411, steps : 47
# loss : 1.0121524
# episode : 412, steps : 110
# episode : 413, steps : 37
# episode : 414, steps : 34
# episode : 415, steps : 36
# episode : 416, steps : 60
# episode : 417, steps : 52
# episode : 418, steps : 68
# episode : 419, steps : 48
# episode : 420, steps : 40
# episode : 421, steps : 46
# loss : 1.3873327
# episode : 422, steps : 91
# episode : 423, steps : 31
# episode : 424, steps : 57
# episode : 425, steps : 78
# episode : 426, steps : 36
# episode : 427, steps : 50
# episode : 428, steps : 45
# episode : 429, steps : 161
# episode : 430, steps : 126
# episode : 431, steps : 37
# loss : 2.152333
# episode : 432, steps : 10
# episode : 433, steps : 9
# episode : 434, steps : 9
# episode : 435, steps : 9
# episode : 436, steps : 8
# episode : 437, steps : 10
# episode : 438, steps : 11
# episode : 439, steps : 9
# episode : 440, steps : 10
# episode : 441, steps : 9
# loss : 2.5043693
# episode : 442, steps : 18
# episode : 443, steps : 43
# episode : 444, steps : 43
# episode : 445, steps : 25
# episode : 446, steps : 14
# episode : 447, steps : 35
# episode : 448, steps : 42
# episode : 449, steps : 45
# episode : 450, steps : 38
# episode : 451, steps : 41
# loss : 0.5292609
# episode : 452, steps : 9
# episode : 453, steps : 9
# episode : 454, steps : 9
# episode : 455, steps : 84
# episode : 456, steps : 9
# episode : 457, steps : 8
# episode : 458, steps : 64
# episode : 459, steps : 9
# episode : 460, steps : 20
# episode : 461, steps : 9
# loss : 0.26418436
# episode : 462, steps : 47
# episode : 463, steps : 48
# episode : 464, steps : 42
# episode : 465, steps : 92
# episode : 466, steps : 44
# episode : 467, steps : 45
# episode : 468, steps : 33
# episode : 469, steps : 52
# episode : 470, steps : 44
# episode : 471, steps : 39
# loss : 500.8213
# episode : 472, steps : 50
# episode : 473, steps : 44
# episode : 474, steps : 63
# episode : 475, steps : 117
# episode : 476, steps : 53
# episode : 477, steps : 73
# episode : 478, steps : 38
# episode : 479, steps : 71
# episode : 480, steps : 42
# episode : 481, steps : 30
# loss : 2.304645
# episode : 482, steps : 35
# episode : 483, steps : 39
# episode : 484, steps : 52
# episode : 485, steps : 14
# episode : 486, steps : 17
# episode : 487, steps : 53
# episode : 488, steps : 49
# episode : 489, steps : 40
# episode : 490, steps : 9
# episode : 491, steps : 9
# loss : 528.29803
# episode : 492, steps : 32
# episode : 493, steps : 26
# episode : 494, steps : 23
# episode : 495, steps : 25
# episode : 496, steps : 41
# episode : 497, steps : 21
# episode : 498, steps : 24
# episode : 499, steps : 26
# episode : 500, steps : 26
# episode : 501, steps : 28
# loss : 527.63586
# episode : 502, steps : 10
# episode : 503, steps : 10
# episode : 504, steps : 10
# episode : 505, steps : 9
# episode : 506, steps : 10
# episode : 507, steps : 9
# episode : 508, steps : 10
# episode : 509, steps : 10
# episode : 510, steps : 11
# episode : 511, steps : 9
# loss : 2.7890537
# episode : 512, steps : 9
# episode : 513, steps : 9
# episode : 514, steps : 8
# episode : 515, steps : 10
# episode : 516, steps : 11
# episode : 517, steps : 10
# episode : 518, steps : 10
# episode : 519, steps : 9
# episode : 520, steps : 9
# episode : 521, steps : 10
# loss : 3.413171
# episode : 522, steps : 24
# episode : 523, steps : 23
# episode : 524, steps : 42
# episode : 525, steps : 20
# episode : 526, steps : 39
# episode : 527, steps : 37
# episode : 528, steps : 27
# episode : 529, steps : 20
# episode : 530, steps : 45
# episode : 531, steps : 43
# loss : 1.1572424
# episode : 532, steps : 58
# episode : 533, steps : 47
# episode : 534, steps : 39
# episode : 535, steps : 37
# episode : 536, steps : 72
# episode : 537, steps : 35
# episode : 538, steps : 33
# episode : 539, steps : 32
# episode : 540, steps : 74
# episode : 541, steps : 47
# loss : 0.78048736
# episode : 542, steps : 9
# episode : 543, steps : 8
# episode : 544, steps : 10
# episode : 545, steps : 11
# episode : 546, steps : 10
# episode : 547, steps : 9
# episode : 548, steps : 9
# episode : 549, steps : 9
# episode : 550, steps : 8
# episode : 551, steps : 11
# loss : 1.1491683
# episode : 552, steps : 10
# episode : 553, steps : 8
# episode : 554, steps : 8
# episode : 555, steps : 10
# episode : 556, steps : 8
# episode : 557, steps : 9
# episode : 558, steps : 9
# episode : 559, steps : 9
# episode : 560, steps : 9
# episode : 561, steps : 8
# loss : 0.9806651
# episode : 562, steps : 10
# episode : 563, steps : 10
# episode : 564, steps : 8
# episode : 565, steps : 8
# episode : 566, steps : 9
# episode : 567, steps : 8
# episode : 568, steps : 8
# episode : 569, steps : 8
# episode : 570, steps : 8
# episode : 571, steps : 9
# loss : 0.91276664
# episode : 572, steps : 105
# episode : 573, steps : 175
# episode : 574, steps : 271
# episode : 575, steps : 203
# episode : 576, steps : 254
# episode : 577, steps : 199
# episode : 578, steps : 271
# episode : 579, steps : 260
# episode : 580, steps : 129
# episode : 581, steps : 206
# loss : 0.6381353
# episode : 582, steps : 22
# episode : 583, steps : 18
# episode : 584, steps : 8
# episode : 585, steps : 12
# episode : 586, steps : 21
# episode : 587, steps : 11
# episode : 588, steps : 21
# episode : 589, steps : 10
# episode : 590, steps : 10
# episode : 591, steps : 30
# loss : 0.8523432
# episode : 592, steps : 47
# episode : 593, steps : 74
# episode : 594, steps : 88
# episode : 595, steps : 33
# episode : 596, steps : 82
# episode : 597, steps : 180
# episode : 598, steps : 39
# episode : 599, steps : 28
# episode : 600, steps : 44
# episode : 601, steps : 86
# loss : 2.249329
# episode : 602, steps : 670
# episode : 603, steps : 376
# episode : 604, steps : 283
# episode : 605, steps : 311
# episode : 606, steps : 808
# episode : 607, steps : 239
# episode : 608, steps : 234
# episode : 609, steps : 300
# episode : 610, steps : 565
# episode : 611, steps : 332
# loss : 2.030582
# episode : 612, steps : 9
# episode : 613, steps : 9
# episode : 614, steps : 9
# episode : 615, steps : 9
# episode : 616, steps : 8
# episode : 617, steps : 11
# episode : 618, steps : 9
# episode : 619, steps : 9
# episode : 620, steps : 8
# episode : 621, steps : 9
# loss : 0.6240252
# episode : 622, steps : 173
# episode : 623, steps : 196
# episode : 624, steps : 145
# episode : 625, steps : 189
# episode : 626, steps : 143
# episode : 627, steps : 152
# episode : 628, steps : 152
# episode : 629, steps : 175
# episode : 630, steps : 298
# episode : 631, steps : 259
# loss : 1.9762377
# episode : 632, steps : 208
# episode : 633, steps : 442
# episode : 634, steps : 236
# episode : 635, steps : 393
# episode : 636, steps : 439
# episode : 637, steps : 476
# episode : 638, steps : 1001
# episode : 639, steps : 310
# episode : 640, steps : 155
# episode : 641, steps : 371
# loss : 0.7536759
# episode : 642, steps : 1001
# episode : 643, steps : 370
# episode : 644, steps : 298
# episode : 645, steps : 178
# episode : 646, steps : 166
# episode : 647, steps : 495
# episode : 648, steps : 267
# episode : 649, steps : 334
# episode : 650, steps : 1001
# episode : 651, steps : 230
# loss : 1.5648146
# episode : 652, steps : 1001
# episode : 653, steps : 1001
# episode : 654, steps : 1001
# episode : 655, steps : 1001
# episode : 656, steps : 1001
# episode : 657, steps : 1001
# episode : 658, steps : 1001
# episode : 659, steps : 1001
# episode : 660, steps : 822
# episode : 661, steps : 1001
# loss : 1.2202618
# episode : 662, steps : 119
# episode : 663, steps : 254
# episode : 664, steps : 227
# episode : 665, steps : 115
# episode : 666, steps : 189
# episode : 667, steps : 125
# episode : 668, steps : 327
# episode : 669, steps : 236
# episode : 670, steps : 189
# episode : 671, steps : 324
# loss : 0.9426564
# episode : 672, steps : 10
# episode : 673, steps : 10
# episode : 674, steps : 9
# episode : 675, steps : 10
# episode : 676, steps : 9
# episode : 677, steps : 9
# episode : 678, steps : 9
# episode : 679, steps : 10
# episode : 680, steps : 10
# episode : 681, steps : 9
# loss : 2.218881
# episode : 682, steps : 1001
# episode : 683, steps : 1001
# episode : 684, steps : 1001
# episode : 685, steps : 1001
# episode : 686, steps : 1001
# episode : 687, steps : 1001
# episode : 688, steps : 1001
# episode : 689, steps : 1001
# episode : 690, steps : 1001
# episode : 691, steps : 1001
# loss : 0.8066939
# episode : 692, steps : 330
# episode : 693, steps : 242
# episode : 694, steps : 347
# episode : 695, steps : 154
# episode : 696, steps : 200
# episode : 697, steps : 152
# episode : 698, steps : 436
# episode : 699, steps : 368
# episode : 700, steps : 237
# episode : 701, steps : 144
# loss : 1.356837
# episode : 702, steps : 301
# episode : 703, steps : 258
# episode : 704, steps : 198
# episode : 705, steps : 162
# episode : 706, steps : 240
# episode : 707, steps : 184
# episode : 708, steps : 322
# episode : 709, steps : 234
# episode : 710, steps : 231
# episode : 711, steps : 291
# loss : 0.8656782
# episode : 712, steps : 1001
# episode : 713, steps : 1001
# episode : 714, steps : 1001
# episode : 715, steps : 1001
# episode : 716, steps : 1001
# episode : 717, steps : 1001
# episode : 718, steps : 1001
# episode : 719, steps : 1001
# episode : 720, steps : 1001
# episode : 721, steps : 1001
# loss : 0.74939597
# episode : 722, steps : 315
# episode : 723, steps : 270
# episode : 724, steps : 148
# episode : 725, steps : 165
# episode : 726, steps : 269
# episode : 727, steps : 247
# episode : 728, steps : 157
# episode : 729, steps : 362
# episode : 730, steps : 428
# episode : 731, steps : 145
# loss : 0.47240034
# episode : 732, steps : 1001
# episode : 733, steps : 1001
# episode : 734, steps : 1001
# episode : 735, steps : 1001
# episode : 736, steps : 1001
# episode : 737, steps : 1001
# episode : 738, steps : 1001
# episode : 739, steps : 1001
# episode : 740, steps : 1001
# episode : 741, steps : 1001
# loss : 0.3018261
# episode : 742, steps : 1001
# episode : 743, steps : 1001
# episode : 744, steps : 588
# episode : 745, steps : 187
# episode : 746, steps : 1001
# episode : 747, steps : 583
# episode : 748, steps : 206
# episode : 749, steps : 831
# episode : 750, steps : 375
# episode : 751, steps : 1001
# loss : 0.816494
# episode : 752, steps : 200
# episode : 753, steps : 192
# episode : 754, steps : 416
# episode : 755, steps : 410
# episode : 756, steps : 166
# episode : 757, steps : 326
# episode : 758, steps : 584
# episode : 759, steps : 410
# episode : 760, steps : 190
# episode : 761, steps : 242
# loss : 0.51528454
# episode : 762, steps : 1001
# episode : 763, steps : 485
# episode : 764, steps : 756
# episode : 765, steps : 1001
# episode : 766, steps : 1001
# episode : 767, steps : 1001
# episode : 768, steps : 516
# episode : 769, steps : 447
# episode : 770, steps : 221
# episode : 771, steps : 317
# loss : 0.6936627
# episode : 772, steps : 143
# episode : 773, steps : 261
# episode : 774, steps : 362
# episode : 775, steps : 381
# episode : 776, steps : 307
# episode : 777, steps : 139
# episode : 778, steps : 229
# episode : 779, steps : 530
# episode : 780, steps : 218
# episode : 781, steps : 167
# loss : 0.44295487
# episode : 782, steps : 514
# episode : 783, steps : 1001
# episode : 784, steps : 1001
# episode : 785, steps : 848
# episode : 786, steps : 326
# episode : 787, steps : 1001
# episode : 788, steps : 377
# episode : 789, steps : 1001
# episode : 790, steps : 1001
# episode : 791, steps : 272
# loss : 0.31061575
# episode : 792, steps : 655
# episode : 793, steps : 1001
# episode : 794, steps : 323
# episode : 795, steps : 150
# episode : 796, steps : 1001
# episode : 797, steps : 1001
# episode : 798, steps : 959
# episode : 799, steps : 562
# episode : 800, steps : 188
# episode : 801, steps : 898
# loss : 0.4950222
# episode : 802, steps : 1001
# episode : 803, steps : 1001
# episode : 804, steps : 1001
# episode : 805, steps : 189
# episode : 806, steps : 563
# episode : 807, steps : 1001
# episode : 808, steps : 1001
# episode : 809, steps : 1001
# episode : 810, steps : 1001
# episode : 811, steps : 1001
# loss : 0.16803724
# episode : 812, steps : 1001
# episode : 813, steps : 1001
# episode : 814, steps : 1001
# episode : 815, steps : 174
# episode : 816, steps : 484
# episode : 817, steps : 150
# episode : 818, steps : 165
# episode : 819, steps : 195
# episode : 820, steps : 426
# episode : 821, steps : 1001
# loss : 0.18905172
# episode : 822, steps : 1001
# episode : 823, steps : 1001
# episode : 824, steps : 1001
# episode : 825, steps : 784
# episode : 826, steps : 1001
# episode : 827, steps : 236
# episode : 828, steps : 427
# episode : 829, steps : 1001
# episode : 830, steps : 359
# episode : 831, steps : 1001
# loss : 0.34086075
# episode : 832, steps : 1001
# episode : 833, steps : 516
# episode : 834, steps : 1001
# episode : 835, steps : 1001
# episode : 836, steps : 974
# episode : 837, steps : 1001
# episode : 838, steps : 871
# episode : 839, steps : 1001
# episode : 840, steps : 1001
# episode : 841, steps : 177
# loss : 0.24083278
# episode : 842, steps : 652
# episode : 843, steps : 1001
# episode : 844, steps : 1001
# episode : 845, steps : 178
# episode : 846, steps : 1001
# episode : 847, steps : 1001
# episode : 848, steps : 173
# episode : 849, steps : 1001
# episode : 850, steps : 1001
# episode : 851, steps : 427
# loss : 0.41947144
# episode : 852, steps : 62
# episode : 853, steps : 47
# episode : 854, steps : 55
# episode : 855, steps : 100
# episode : 856, steps : 133
# episode : 857, steps : 41
# episode : 858, steps : 169
# episode : 859, steps : 93
# episode : 860, steps : 121
# episode : 861, steps : 81
# loss : 0.403435
# episode : 862, steps : 1001
# episode : 863, steps : 1001
# episode : 864, steps : 1001
# episode : 865, steps : 1001
# episode : 866, steps : 1001
# episode : 867, steps : 1001
# episode : 868, steps : 1001
# episode : 869, steps : 171
# episode : 870, steps : 1001
# episode : 871, steps : 1001
# loss : 0.5193857
# episode : 872, steps : 1001
# episode : 873, steps : 1001
# episode : 874, steps : 1001
# episode : 875, steps : 1001
# episode : 876, steps : 524
# episode : 877, steps : 1001
# episode : 878, steps : 1001
# episode : 879, steps : 188
# episode : 880, steps : 1001
# episode : 881, steps : 1001
# loss : 0.67341965
# episode : 882, steps : 1001
# episode : 883, steps : 494
# episode : 884, steps : 1001
# episode : 885, steps : 1001
# episode : 886, steps : 1001
# episode : 887, steps : 145
# episode : 888, steps : 1001
# episode : 889, steps : 1001
# episode : 890, steps : 1001
# episode : 891, steps : 205
# loss : 0.25998747
# episode : 892, steps : 1001
# episode : 893, steps : 1001
# episode : 894, steps : 156
# episode : 895, steps : 1001
# episode : 896, steps : 1001
# episode : 897, steps : 1001
# episode : 898, steps : 137
# episode : 899, steps : 1001
# episode : 900, steps : 141
# episode : 901, steps : 1001
# loss : 0.26300478
# episode : 902, steps : 1001
# episode : 903, steps : 1001
# episode : 904, steps : 1001
# episode : 905, steps : 1001
# episode : 906, steps : 1001
# episode : 907, steps : 1001
# episode : 908, steps : 198
# episode : 909, steps : 1001
# episode : 910, steps : 1001
# episode : 911, steps : 166
# loss : 0.12776104
# episode : 912, steps : 227
# episode : 913, steps : 1001
# episode : 914, steps : 168
# episode : 915, steps : 1001
# episode : 916, steps : 1001
# episode : 917, steps : 1001
# episode : 918, steps : 507
# episode : 919, steps : 185
# episode : 920, steps : 1001
# episode : 921, steps : 164
# loss : 0.3035616
# episode : 922, steps : 1001
# episode : 923, steps : 1001
# episode : 924, steps : 647
# episode : 925, steps : 1001
# episode : 926, steps : 1001
# episode : 927, steps : 723
# episode : 928, steps : 1001
# episode : 929, steps : 176
# episode : 930, steps : 506
# episode : 931, steps : 1001
# loss : 0.66544515
# episode : 932, steps : 1001
# episode : 933, steps : 448
# episode : 934, steps : 730
# episode : 935, steps : 867
# episode : 936, steps : 1001
# episode : 937, steps : 1001
# episode : 938, steps : 226
# episode : 939, steps : 1001
# episode : 940, steps : 371
# episode : 941, steps : 294
# loss : 0.6728961
# episode : 942, steps : 373
# episode : 943, steps : 362
# episode : 944, steps : 991
# episode : 945, steps : 1001
# episode : 946, steps : 147
# episode : 947, steps : 477
# episode : 948, steps : 1001
# episode : 949, steps : 531
# episode : 950, steps : 1001
# episode : 951, steps : 537
# loss : 0.2964709
# episode : 952, steps : 1001
# episode : 953, steps : 1001
# episode : 954, steps : 1001
# episode : 955, steps : 1001
# episode : 956, steps : 1001
# episode : 957, steps : 504
# episode : 958, steps : 553
# episode : 959, steps : 1001
# episode : 960, steps : 292
# episode : 961, steps : 1001
# loss : 0.48717445
# episode : 962, steps : 161
# episode : 963, steps : 140
# episode : 964, steps : 919
# episode : 965, steps : 954
# episode : 966, steps : 177
# episode : 967, steps : 150
# episode : 968, steps : 1001
# episode : 969, steps : 1001
# episode : 970, steps : 463
# episode : 971, steps : 1001
# loss : 0.20502746
# episode : 972, steps : 372
# episode : 973, steps : 334
# episode : 974, steps : 418
# episode : 975, steps : 1001
# episode : 976, steps : 359
# episode : 977, steps : 142
# episode : 978, steps : 1001
# episode : 979, steps : 1001
# episode : 980, steps : 980
# episode : 981, steps : 912
# loss : 0.27505738
# episode : 982, steps : 1001
# episode : 983, steps : 1001
# episode : 984, steps : 1001
# episode : 985, steps : 1001
# episode : 986, steps : 167
# episode : 987, steps : 174
# episode : 988, steps : 1001
# episode : 989, steps : 1001
# episode : 990, steps : 806
# episode : 991, steps : 171
# loss : 0.15821385
# episode : 992, steps : 1001
# episode : 993, steps : 199
# episode : 994, steps : 1001
# episode : 995, steps : 1001
# episode : 996, steps : 134
# episode : 997, steps : 1001
# episode : 998, steps : 1001
# episode : 999, steps : 540
